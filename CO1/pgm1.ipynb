# %%
import numpy as np
from PIL import Image
from scipy import ndimage 
from matplotlib import pyplot as plt
a=Image.open('itachi.jpg')
plt.imshow(a)
b=np.array(a)
x=ndimage.rotate(b,120)
plt.imshow(x)

# %%
d=ndimage.zoom(b,1.1)
e=Image.fromarray(d)
plt.imshow(e)
